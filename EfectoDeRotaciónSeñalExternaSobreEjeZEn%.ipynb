# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
from qiskit import IBMQ
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
backend = provider.get_backend('ibmq_qasm_simulator')
# Out:
# ibmqfactory.load_account:WARNING:2022-07-27 17:41:06,768: Credentials are already in use. The existing account in the session will be replaced.

# %%
from qiskit.tools.visualization import plot_state_city, plot_bloch_multivector, plot_state_paulivec, plot_state_hinton, plot_state_qsphere

# %%
from qiskit.tools.visualization import plot_histogram

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import execute, BasicAer

from math import pi

# %%
circ1 = QuantumCircuit(1,1)

circ1.h(0)
circ1.rz(0,0)
circ1.h(0)
circ1.measure(0,0)

circ1.draw()

# execute the quantum circuit
backend = BasicAer.get_backend('qasm_simulator') # the device to run on
result = execute(circ1, backend, shots=1000).result()
counts  = result.get_counts(circ1)
print(counts)

plot_histogram(counts)
# Out:
# {'0': 1000}

# %%
from qiskit_textbook.widgets import plot_bloch_vector_spherical
coords = [pi/2,0,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
coords = [0,pi/2,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
# execute the quantum circuit
backend = BasicAer.get_backend('statevector_simulator') # the device to run on
result = execute(circ1, backend).result()
psi  = result.get_statevector(circ1)

plot_bloch_multivector(psi, title="Bloch Sphere (Measurement 'Most probable')")

# %%
circ1 = QuantumCircuit(1,1)

circ1.h(0)
circ1.rz(pi/8,0)
circ1.h(0)
circ1.measure(0,0)

circ1.draw()

# execute the quantum circuit
backend = BasicAer.get_backend('qasm_simulator') # the device to run on
second_result = execute(circ1, backend, shots=1000).result()
second_counts  = second_result.get_counts(circ1)
print(second_counts)

plot_histogram(second_counts)
# Out:
# {'0': 951, '1': 49}

# %%
coords = [pi/2,pi/8,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
coords = [-pi/8,pi/2,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
# execute the quantum circuit
backend = BasicAer.get_backend('statevector_simulator') # the device to run on
result = execute(circ1, backend).result()
psi  = result.get_statevector(circ1)

plot_bloch_multivector(psi, title="Bloch Sphere (Measurement)")

# %%
circ1 = QuantumCircuit(1,1)

circ1.h(0)
circ1.rz(pi/4,0)
circ1.h(0)
circ1.measure(0,0)

circ1.draw()

# execute the quantum circuit
backend = BasicAer.get_backend('qasm_simulator') # the device to run on
terc_result = execute(circ1, backend, shots=1000).result()
terc_counts  = terc_result.get_counts(circ1)
print(terc_counts)

plot_histogram(terc_counts)
# Out:
# {'0': 846, '1': 154}

# %%
coords = [pi/2,pi/4,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
coords = [-pi/4,pi/2,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
# execute the quantum circuit
backend = BasicAer.get_backend('statevector_simulator') # the device to run on
result = execute(circ1, backend).result()
psi  = result.get_statevector(circ1)

plot_bloch_multivector(psi, title="Bloch Sphere (Measurement)")

# %%
circ1 = QuantumCircuit(1,1)

circ1.h(0)
circ1.rz(3*pi/8,0)
circ1.h(0)
circ1.measure(0,0)

circ1.draw()

# execute the quantum circuit
backend = BasicAer.get_backend('qasm_simulator') # the device to run on
cuart_result = execute(circ1, backend, shots=1000).result()
cuart_counts  = cuart_result.get_counts(circ1)
print(cuart_counts)

plot_histogram(cuart_counts)
# Out:
# {'0': 702, '1': 298}

# %%
coords = [pi/2,3*pi/8,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
coords = [-3*pi/8,pi/2,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
# execute the quantum circuit
backend = BasicAer.get_backend('statevector_simulator') # the device to run on
result = execute(circ1, backend).result()
psi  = result.get_statevector(circ1)

plot_bloch_multivector(psi, title="Bloch Sphere (Measurement)")

# %%
circ1 = QuantumCircuit(1,1)

circ1.h(0)
circ1.rz(pi/2,0)
circ1.h(0)
circ1.measure(0,0)

circ1.draw()

# execute the quantum circuit
backend = BasicAer.get_backend('qasm_simulator') # the device to run on
quint_result = execute(circ1, backend, shots=1000).result()
quint_counts  = quint_result.get_counts(circ1)
print(quint_counts)

plot_histogram(quint_counts)
# Out:
# {'1': 516, '0': 484}

# %%
coords = [pi/2,pi/2,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
coords = [-pi/2,pi/2,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
# execute the quantum circuit
backend = BasicAer.get_backend('statevector_simulator') # the device to run on
result = execute(circ1, backend).result()
psi  = result.get_statevector(circ1)

plot_bloch_multivector(psi, title="Bloch Sphere (Measurement)")

# %%
circ1 = QuantumCircuit(1,1)

circ1.h(0)
circ1.rz(5*pi/8,0)
circ1.h(0)
circ1.measure(0,0)

circ1.draw()

# execute the quantum circuit
backend = BasicAer.get_backend('qasm_simulator') # the device to run on
sext_result = execute(circ1, backend, shots=1000).result()
sext_counts  = sext_result.get_counts(circ1)
print(sext_counts)

plot_histogram(sext_counts)
# Out:
# {'1': 681, '0': 319}

# %%
coords = [pi/2,5*pi/8,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
coords = [-5*pi/8,pi/2,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
# execute the quantum circuit
backend = BasicAer.get_backend('statevector_simulator') # the device to run on
result = execute(circ1, backend).result()
psi  = result.get_statevector(circ1)

plot_bloch_multivector(psi, title="Bloch Sphere (Measurement)")

# %%
circ1 = QuantumCircuit(1,1)

circ1.h(0)
circ1.rz(3*pi/4,0)
circ1.h(0)
circ1.measure(0,0)

circ1.draw()

# execute the quantum circuit
backend = BasicAer.get_backend('qasm_simulator') # the device to run on
sept_result = execute(circ1, backend, shots=1000).result()
sept_counts  = sept_result.get_counts(circ1)
print(sept_counts)

plot_histogram(sept_counts)
# Out:
# {'1': 845, '0': 155}

# %%
coords = [pi/2,3*pi/4,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
coords = [-3*pi/4,pi/2,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
# execute the quantum circuit
backend = BasicAer.get_backend('statevector_simulator') # the device to run on
result = execute(circ1, backend).result()
psi  = result.get_statevector(circ1)

plot_bloch_multivector(psi, title="Bloch Sphere (Measurement)")

# %%
circ1 = QuantumCircuit(1,1)

circ1.h(0)
circ1.rz(7*pi/8,0)
circ1.h(0)
circ1.measure(0,0)

circ1.draw()

# execute the quantum circuit
backend = BasicAer.get_backend('qasm_simulator') # the device to run on
oct_result = execute(circ1, backend, shots=1000).result()
oct_counts  = oct_result.get_counts(circ1)
print(oct_counts)

plot_histogram(oct_counts)
# Out:
# {'1': 963, '0': 37}

# %%
coords = [pi/2,7*pi/8,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
coords = [-7*pi/8,pi/2,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
# execute the quantum circuit
backend = BasicAer.get_backend('statevector_simulator') # the device to run on
result = execute(circ1, backend).result()
psi  = result.get_statevector(circ1)

plot_bloch_multivector(psi, title="Bloch Sphere (Measurement)")

# %%
circ1 = QuantumCircuit(1,1)

circ1.h(0)
circ1.rz(pi,0)
circ1.h(0)
circ1.measure(0,0)

circ1.draw()

# execute the quantum circuit
backend = BasicAer.get_backend('qasm_simulator') # the device to run on
nov_result = execute(circ1, backend, shots=1000).result()
nov_counts  = nov_result.get_counts(circ1)
print(nov_counts)

plot_histogram(nov_counts)
# Out:
# {'1': 1000}

# %%
coords = [pi/2,pi,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
coords = [-pi,pi/2,1] # [Theta, Phi, Radius]
plot_bloch_vector_spherical(coords) # Bloch Vector with spherical coordinates

# %%
# execute the quantum circuit
backend = BasicAer.get_backend('statevector_simulator') # the device to run on
result = execute(circ1, backend).result()
psi  = result.get_statevector(circ1)

plot_bloch_multivector(psi, title="Bloch Sphere (Measurement)")

# %%
legend = ['0', 'Pi/8' , 'Pi/4' , '3Pi/8' , 'Pi/2' , '5Pi/8' , '3Pi/4' , '7Pi/8' , 'Pi']
plot_histogram([counts, second_counts, terc_counts, cuart_counts, quint_counts, sext_counts, sept_counts, oct_counts, nov_counts], legend=legend, title = 'Desglose de probabilidades (0 --> Pi)')
